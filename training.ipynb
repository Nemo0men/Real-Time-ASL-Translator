# %% [markdown]
# Resouces Used:
#
# wget.download('https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/_downloads/da4babe668a8afb093cc7776d7e630f3/generate_tfrecord.py')
#
# Setup https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/install.html

# %% [markdown]
# # Paths

# %%
WORKSPACE_PATH = 'ImageCollection/Tensorflow/workspace'
SCRIPTS_PATH = 'ImageCollection/Tensorflow/scripts'
APIMODEL_PATH = 'ImageCollection/Tensorflow/models'
ANNOTATION_PATH = WORKSPACE_PATH+'/annotations'
IMAGE_PATH = WORKSPACE_PATH+'/images'
MODEL_PATH = WORKSPACE_PATH+'/models'
PRETRAINED_MODEL_PATH = WORKSPACE_PATH+'/pre-trained-models'
CONFIG_PATH = MODEL_PATH+'/my_ssd_mobnet/pipeline.config'
CHECKPOINT_PATH = MODEL_PATH+'/my_ssd_mobnet/'

# %% [markdown]
# # Label Map

# %%
import os

labels = [
    {'name':'hello', 'id':1},
    {'name':'thanks', 'id':2},
    {'name':'I love you.', 'id':3},
    {'name':'yes', 'id':4},
    {'name':'no', 'id':5},
    {'name':'brother', 'id':6},
    {'name':'help', 'id':7},
    {'name':'mom', 'id':8},
    {'name':'please', 'id':9},
    {'name':'sad', 'id':10}
]

os.makedirs(ANNOTATION_PATH, exist_ok=True)


with open(ANNOTATION_PATH + '\label_map.pbtxt', 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # Tensorflow Records

# %%
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}
# !python {SCRIPTS_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# WARNING:tensorflow:From c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\object_detection\utils\label_map_util.py:131: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Traceback (most recent call last):
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\ImageCollection\Tensorflow\scripts\generate_tfrecord.py", line 62, in <module>
#     label_map_dict = label_map_util.get_label_map_dict(label_map)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\object_detection\utils\label_map_util.py", line 163, in get_label_map_dict
#     label_map = load_labelmap(label_map_path)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\object_detection\utils\label_map_util.py", line 132, in load_labelmap
#     label_map_string = fid.read()
#                        ^^^^^^^^^^
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\tensorflow\python\lib\io\file_io.py", line 116, in read
#     self._preread_check()
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\tensorflow\python\lib\io\file_io.py", line 77, in _preread_check
#     self._read_buf = _pywrap_file_io.BufferedInputStream(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: __init__(): incompatible constructor arguments. The following argument types are supported:
#     1. tensorflow.python.lib.io._pywrap_file_io.BufferedInputStream(filename: str, buffer_size: int, token: tensorflow.python.lib.io._pywrap_file_io.TransactionToken = None)
#
# Invoked with: item {
#   name: "hello"
#   id: 1
# }
# item {
#   name: "thanks"
#   id: 2
# }
# item {
#   name: "I love you."
#   id: 3
# }
# item {
#   name: "yes"
#   id: 4
# }
# item {
#   name: "no"
#   id: 5
# }
# item {
#   name: "brother"
#   id: 6
# }
# item {
#   name: "help"
#   id: 7
# }
# item {
#   name: "mom"
#   id: 8
# }
# item {
#   name: "please"
#   id: 9
# }
# item {
#   name: "sad"
#   id: 10
# }
# , 524288
# WARNING:tensorflow:From c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\object_detection\utils\label_map_util.py:131: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Traceback (most recent call last):
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\ImageCollection\Tensorflow\scripts\generate_tfrecord.py", line 62, in <module>
#     label_map_dict = label_map_util.get_label_map_dict(label_map)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\object_detection\utils\label_map_util.py", line 163, in get_label_map_dict
#     label_map = load_labelmap(label_map_path)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\object_detection\utils\label_map_util.py", line 132, in load_labelmap
#     label_map_string = fid.read()
#                        ^^^^^^^^^^
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\tensorflow\python\lib\io\file_io.py", line 116, in read
#     self._preread_check()
#   File "c:\Users\chank\vscode\asl translator\ai-hardware-project-aibrawlers\venv\Lib\site-packages\tensorflow\python\lib\io\file_io.py", line 77, in _preread_check
#     self._read_buf = _pywrap_file_io.BufferedInputStream(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: __init__(): incompatible constructor arguments. The following argument types are supported:
#     1. tensorflow.python.lib.io._pywrap_file_io.BufferedInputStream(filename: str, buffer_size: int, token: tensorflow.python.lib.io._pywrap_file_io.TransactionToken = None)
#
# Invoked with: item {
#   name: "hello"
#   id: 1
# }
# item {
#   name: "thanks"
#   id: 2
# }
# item {
#   name: "I love you."
#   id: 3
# }
# item {
#   name: "yes"
#   id: 4
# }
# item {
#   name: "no"
#   id: 5
# }
# item {
#   name: "brother"
#   id: 6
# }
# item {
#   name: "help"
#   id: 7
# }
# item {
#   name: "mom"
#   id: 8
# }
# item {
#   name: "please"
#   id: 9
# }
# item {
#   name: "sad"
#   id: 10
# }
# , 524288
